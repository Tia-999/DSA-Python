# %% [markdown]
# # Stack

# %% [markdown]
# In python list can be used as a way to implement stack, but it's not very efficient instead we can use collections deque for our goal that works on doubly linked list

# %% [markdown]
# LIFO - push/pop - O(1) ,searching - O(n)  e.g function calling, undo

# %%
from collections import deque

# %%
class Stack:
    def __init__(self):
        self.container  = deque()
    def push(self,data):
        self.container.append(data)
    def pop(self):
        return self.container.pop()
    def peek(self):
        returnself.container[-1]
    def is_empty(self):
        return len(self.container) == 0
    def size(self):
        return len(self.container)

# %%
s = Stack()
s.push(4)
s.pop()
# Out:
# 4

# %% [markdown]
# Write a function in python that can reverse a string using stack data structure.

# %%
def rev_string(my_string):
    rstr = ' '
    for char in enumerate(my_string):
        s.push(char)
    while s.size():
         rstr += s.pop()[1]
    return rstr

# %%
rev_string("We will conquere COVID-19")
# Out:
# ' 91-DIVOC ereuqnoc lliw eW'

# %% [markdown]
# Write a function in python that checks if paranthesis in the string are balanced or not. Possible parantheses are "{}',"()" or "[]"

# %%
def is_balanced(str):
    dict_b = {')': '(', '}': '{', ']': '['}
    s = Stack()
    for char in str:
        if char in dict_b.values():
            s.push(char)
        elif char in dict_b:
            if s.is_empty() or s.pop() != dict_b[char]:
                return False
    return s.is_empty()

# %%
print(is_balanced("({[]})"))   # True ✅
print(is_balanced("({[)]}"))   # False ❌
print(is_balanced("((("))      # False ❌
print(is_balanced("(()[])"))   # True ✅
# Out:
# True
# False
# False
# True
