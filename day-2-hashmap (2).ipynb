# %% [markdown]
# # HashTable without Colllision

# %%
class HashTable:
    def __init__(self):
        self.MAX = 100
        self.arr = [None for i in range(self.MAX)]
    def get_hash(self,key):
        h = 0
        for char in key:
            h += ord(char)
        return h % self.MAX
    def __setitem__(self, key ,val):
        h = self.get_hash(key)
        self.arr[h] = val
    def __getitem__(self, key):
        h = self.get_hash(key)
        return self.arr[h]
    def __delitem__(self,key):
        h = self.get_hash(key)
        self.arr[h] = None

# %%
t = HashTable()
t['march 6']= 130

# %%
t['march 6']
# Out:
# 130

# %% [markdown]
# Seperate Chanining method you store a linked list or list instead of directly storing a value to corresponding key.
#
# Linear Probing refers to searching for next available slot for storing value

# %% [markdown]
# # HashTable with Collison

# %%
class HashTable:
    def __init__(self):
        self.MAX = 10
        self.arr = [[] for i in range(self.MAX)] # we are setting none beacuse we are
                                                 #not just storing value but key value pair
    def get_hash(self,key):
        h = 0
        for char in key:
            h += ord(char)
        return h % self.MAX
        
    def __setitem__(self, key ,val):
        h = self.get_hash(key)
        found = False
        for idx,element in enumerate(self.arr[h]): # element = (key,value)
            if len(element) == 2 and element[0] == key:
                self.arr[h][idx] = (key,val) # new tuple
                found = True
                break 
        if not found:
           self.arr[h].append((key,val))
        
    def __getitem__(self, key):
        h = self.get_hash(key)
        for element in self.arr[h]:
            if element[0] == key:
                 return self.arr[1]
    
        
    def __delitem__(self,key):
        h = self.get_hash(key)
        for idx, element in enumerate(self.arr[h]):
          if len(element) == 2 and element[0] == key:
             del  self.arr[h][idx]

# %%
t = HashTable()

# %%
t.arr
# Out:
# [[], [], [], [], [], [], [], [], [], []]

# %% [markdown]
# # Exercises

# %%
t = {
    'Jan 1': 27,
    'Jan 2': 31,
    'Jan 3': 23,
    'Jan 4': 34,
    'Jan 5': 37,
    'Jan 6': 38,
    'Jan 7': 29,
    'Jan 8': 30,
    'Jan 9': 35,
    'Jan 10': 30
}

# %%
a_list = list(t.values())
print(a_list)
# Out:
# [27, 31, 23, 34, 37, 38, 29, 30, 35, 30]

# %%
sum(a_list[:7])/len(a_list[:7])
# Out:
# 31.285714285714285

# %%
max(a_list[0:10])
# Out:
# 38

# %%
t['Jan 9']
# Out:
# 35

# %%
t['Jan 4']
# Out:
# 34

# %%
word_count = {}

with open("poem.txt","r") as f:
    for line in f:
        words = lines.split(' ')
        for word in words:
            word = word.replace('\n','')
            if word in word_count:
                word_count[word] += 1
            else:
                 word_count[word] = 1

# %%
class HashTable:
    def __init__(self):
        self.MAX = 10
        self.arr = [None for i in range(self.MAX)] # we are setting none beacuse we are
                                                 #not just storing value but key value pair
    def get_hash(self,key):
        h = 0
        for char in key:
            h += ord(char)
        return h % self.MAX
        
    def get_prob_range(self,index):
        return [*range(index,len(self.arr))]+[*range(0,index)]

    def find_slot(self,key,index):
        prob_range = self.get_prob_range(index)
        for slot in prob_range:
            if self.arr[slot] == None:
                return slot
            if self.arr[slot][0] == key:
                return slot
        raise Exception("Hashmap Full")
            
    
    def __setitem__(self, key ,val):
        h = self.get_hash(key)
        if self.arr[h] is None:
            self.arr[h] =(key,val)
        else:
            new_h = self.find_slot(key,h)
            self.arr[new_h] = (key,val)
        print(self.arr)
        
        
    def __getitem__(self, key):
        h = self.get_hash(key)
        if self.arr[h] is None:
            return
        prob_range = self.get_prob_range(h)
        for slot in prob_range:
            element = self.arr[slot]
            if element is None:
                return
            if element[0] == key:
                return element[1]
    
        
    def __delitem__(self,key):
        h = self.get_hash(key)
        prob_range = self.get_prob_range(h)
        for slot in prob_range:
            if self.arr[slot] is None:
                return
            if self.arr[slot][0] == key:
               self.arr[slot] = None
        print(self.arr)

# %%
t = HashTable()
t["march 6"] = 20
t["march 17"] =  88
# Out:
# [None, None, None, None, None, None, None, None, None, ('march 6', 20)]
# [('march 17', 88), None, None, None, None, None, None, None, None, ('march 6', 20)]

# %%
t["april 3"]=234234
# Out:
# [('march 17', 88), ('april 3', 234234), None, None, None, None, None, None, None, ('march 6', 20)]

# %%
t["May 7"]=47
# Out:
# [('march 17', 88), ('april 3', 234234), ('May 7', 47), None, None, None, None, None, None, ('march 6', 20)]

# %%
del t["april 3"]

# %%
t.arr
# Out:
# [('march 17', 88),
#  None,
#  ('May 7', 47),
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ('march 6', 20)]
